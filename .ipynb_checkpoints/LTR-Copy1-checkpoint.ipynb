# %%
import json

with open("SweLL_correctionTags_502essays.json", "r") as f:
    d = json.load(f)

all_s_wo = []
errors = []
for key, value in d.items():
    k = json.loads(value)
    keys = list(k['edges'].keys())
    for edge in keys:
        error = k['edges'][edge]
        if error['labels'] == ['S-WO']:
            all_s_wo.append(error['ids'])

# c = Counter(errors)
# print(c)
# break
print(len(all_s_wo))
print(all_s_wo)
# Out:
# 132
# [['s107', 't871'], ['s237', 's238', 't489', 't504'], ['s233', 's234', 't688', 't718'], ['s301', 't899'], ['s132', 't305'], ['s192', 's193', 's194', 's195', 's196', 's197', 't194', 't195', 't196', 't895', 't897', 't900'], ['s125', 't427'], ['s443', 't924'], ['s75', 't447'], ['s478', 's479', 's480', 't962', 't963', 't979'], ['s168', 't542'], ['s165', 's166', 't545', 't565'], ['s194', 't584'], ['s74', 't128'], ['s603', 't1797'], ['s759', 's760', 's761', 't1961', 't1962', 't1963'], ['s190', 't431'], ['s406', 't1729'], ['s738', 't1710'], ['s923', 't1886'], ['s518', 's519', 't1706', 't1707'], ['s520', 't1710'], ['s1165', 't2380'], ['s430', 's431', 't773', 't782'], ['s125', 't332'], ['s123', 't348'], ['s119', 't1217'], ['s354', 't1471'], ['s73', 't287'], ['s36', 't204'], ['s34', 't217'], ['s88', 't255'], ['s83', 't309'], ['s39', 't149'], ['s70', 't215'], ['s110', 't272'], ['s156', 't377'], ['s221', 't410'], ['s236', 't538'], ['s64', 't178'], ['s192', 's193', 't854', 't866'], ['s1532', 's1534', 's1535', 't1184', 't1187', 't1193'], ['s384', 't1501'], ['s795', 's796', 't2088', 't2089'], ['s1116', 't2426'], ['s1162', 't2375'], ['s64', 't1328'], ['s86', 't265'], ['s88', 't327'], ['s90', 't310'], ['s111', 't438'], ['s35', 's36', 's37', 's38', 's41', 's42', 't204', 't205', 't35', 't36', 't37', 't42'], ['s70', 't338'], ['s113', 't419'], ['s392', 't1153'], ['s122', 't217'], ['s120', 't227'], ['s138', 't518'], ['s63', 't208'], ['s61', 't171'], ['s180', 't445'], ['s208', 't349'], ['s435', 's436', 't2063', 't2077'], ['s326', 't1291'], ['s948', 't1934'], ['s22', 't261'], ['s265', 't680'], ['s636', 's637', 't1356', 't1357'], ['s145', 't344'], ['s19', 's20', 's21', 't186', 't191', 't197'], ['s132', 't312'], ['s391', 's392', 't966', 't967'], ['s347', 't1126'], ['s370', 't1150'], ['s419', 't1196'], ['s492', 't1277'], ['s202', 's203', 's204', 's205', 't1199', 't745', 't746', 't747'], ['s231', 't659'], ['s294', 't717'], ['s129', 's130', 's131', 't566', 't567', 't568'], ['s443', 't1162'], ['s506', 't1224'], ['s404', 't1048'], ['s172', 't580'], ['s164', 's165', 's166', 's167', 't576', 't577', 't578', 't579'], ['s225', 't637'], ['s321', 't674'], ['s54', 't382'], ['s24', 't640'], ['s117', 't283'], ['s109', 's110', 't412', 't496'], ['s69', 's70', 't665', 't70'], ['s195', 's196', 't1083', 't1086'], ['s360', 't834'], ['s403', 's404', 's405', 't404', 't405', 't805'], ['s155', 't318'], ['s205', 't695'], ['s316', 't985'], ['s315', 't990'], ['s32', 't985'], ['s195', 't784'], ['s123', 't459'], ['s122', 't495'], ['s137', 't513'], ['s100', 't821'], ['s302', 's303', 't1146', 't1222'], ['s229', 't540'], ['s192', 't561'], ['s669', 't1942'], ['s185', 't449'], ['s29', 't171'], ['s413', 't1155'], ['s185', 't885'], ['s184', 't890'], ['s69', 's71', 's72', 's75', 's76', 't1889', 't1891', 't1892', 't602', 't620'], ['s1', 't225'], ['s522', 's523', 't1393', 't523'], ['s140', 't531'], ['s54', 's55', 't415', 't422'], ['s98', 't511'], ['s152', 't731'], ['s316', 't1012'], ['s402', 't1132'], ['s138', 't553'], ['s38', 't261'], ['s97', 't229'], ['s463', 't852'], ['s31', 't239'], ['s5', 't321'], ['s467', 't1097'], ['s266', 's267', 't1139', 't1146'], ['s406', 't1184']]

# %%
def pos_thingie(sentence):
    #!/usr/bin/env python3
    """Python 3 Example script for sending queries to the Sparv 2 API."""

    import json

    # URL to the Sparv 2 API:
    sparv_url = "https://ws.spraakbanken.gu.se/ws/sparv/v2/"

    # The input text to be processed by Sparv:
    sparv_input = str(sentence)

    # Optional settings, specifying what analysis should be done (in this case compound analysis only):
    # Check https://ws.spraakbanken.gu.se/ws/sparv/v2/#settings for more info
    sparv_settings = json.dumps({
        "corpus": "Korpusnamn",
        "lang": "sv",
        "textmode": "plain",
        "positional_attributes": {
            "lexical_attributes": [
                "pos",
                "msd",
                "lemma"
            ]
        },
        "text_attributes": {
            "readability_metrics": [
                "lix",
                "ovix",
                "nk"
            ]
        }
    })

    query_parameters = {"text": sparv_input, "settings": sparv_settings}


    #-------------------------------------------------------------------
    # Example using Python's built-in urllib.request
    # https://docs.python.org/3/library/urllib.request.html
    #-------------------------------------------------------------------

    import urllib.request
    import urllib.parse

    enc_query = urllib.parse.urlencode(query_parameters).encode("UTF-8")
    resp = urllib.request.urlopen(sparv_url, data=enc_query).read()
    
    print("\nSparv response using urllib:\n")
    o = resp.decode("UTF-8")
    print(o)

    #-------------------------------------------------------------------
    # Example using the more intuitive but third-pary Requests library
    # https://docs.python-requests.org/en/master/
    #-------------------------------------------------------------------

    import requests

    response = requests.get(sparv_url, params=query_parameters)

    print("\n\nSparv response using the requests library:\n")
    print(response.text)
    
    return o

# %%
def printss(s1, s2):
    print("ORIGINAL:")
    good = pos_thingie(s1)
    print(good)
    print("_____________________________________________________")
    print("CORRECTED:")
    bad = pos_thingie(s2)
    print(bad)
    
    return str(good), str(bad)

# %%
import pandas as pd
import csv

file = "Sheet1.csv"
df = pd.read_csv(file)

pairs = []

with open(file, "r") as f:
    reader = csv.reader(f, delimiter="\t")
    for i, line in enumerate(reader):
        l = line[0].split(',')
        if l[6] == 'S-FinV':
            pairs.append((l[2], l[3]))
            
print(pairs)
print(len(pairs))
# Out:
# [('När jag kom först 2012 jag bodde i en kommunal lägenhet med 3 andra personer .', 'När jag först kom 2012 bodde jag i en kommunal lägenhet med 3 andra personer .'), ('Ibland vi kan titta och lyssna på hur det funkar .', 'Ibland kan vi titta och lyssna på hur det funkar .'), ('Ibland kan vi titta och lyssna på hur funkar det .', 'Ibland kan vi titta och lyssna på hur det funkar .'), ('Men nu jag är inte intresserad av den längre .', 'Men nu är jag inte intresserad av den längre .'), ('Dessutom kursen passar inte bra för mig .', 'Dessutom passar kursen inte bra för mig .'), ('Tyvärr någonting har hänt som gör att jag inte kan gå på kursen och jag önskar att få pengarna tillbaka .', 'Tyvärr har någonting hänt som gör att jag inte kan gå på kursen och jag önskar att få pengarna tillbaka .'), ('För det första måste jag stanna där lite längre så kan jag inte börja på den här kursen .', 'För det första måste jag stanna där lite längre så jag kan inte börja på den här kursen .'), ('För det andra har jag lite pengar och behöver jag mer pengar för att betala för biljetterna för resan .', 'För det andra har jag lite pengar och jag behöver mer pengar för att betala för biljetterna för resan .'), ('Så önskar jag att du betalar tillbaka min kursavgift så snart som möjligt .', 'Så jag önskar att du betalar tillbaka min kursavgift så snart som möjligt .'), ('Därför jag vill inte flytta .', 'Därför vill jag inte flytta .'), ('Pga såna grejer jag funderar på att köpa en egen lägenhet .', 'Pga såna grejer funderar jag på att köpa en egen lägenhet .'), ('Ibland mormor kommer för att stanna med oss flera dagar .', 'Ibland kommer mormor för att stanna med oss flera dagar .'), ('När man flyttar till en ny stad man är ensam de första dagarna .', 'När man flyttar till en ny stad är man ensam de första dagarna .'), ('Nu min lärare heter Karin .', 'Nu heter min lärare Karin .'), ('Därför jag tycker om havet .', 'Därför tycker jag om havet .'), ('Om man vill äta fisk man kan gå till havet och hitta fisk i det .', 'Om man vill äta fisk kan man gå till havet och hitta fisk i det .'), ('När jag blir arg jag vill gå till havet och titta på det så jag blir lugn .', 'När jag blir arg vill jag gå till havet och titta på det så jag blir lugn .'), ('När man åker dit man ser natur som många träd och stränder .', 'När man åker dit ser man natur som många träd och stränder .'), ('Där alla människor är snälla och hjälpsamma .', 'Där är alla människor snälla och hjälpsamma .'), ('Jag tycker om att bo tillsamans med min sambo men ibland det är lite svårt .', 'Jag tycker om att bo tillsamans med min sambo men ibland är det lite svårt .'), ('Där jag bodde i A-stad med min mamma och hennes hundar i hennes hus .', 'Där bodde jag i A-stad med min mamma och hennes hundar i hennes hus .'), ('Trots allt jag är jätteglad att bo där .', 'Trots allt är jag jätteglad att bo där .'), ('Från mitt fönster jag kan se Strandvägen-gen busshållplats .', 'Från mitt fönster kan jag se Strandvägen-gen busshållplats .'), ('Nästa dag hon kom till mig och berättade samma sak för mig och jag blev väldigt glad och vi träffades varje dag .', 'Nästa dag kom hon till mig och berättade samma sak för mig och jag blev väldigt glad och vi träffades varje dag .'), ('Så vår kärlek började .', 'Så började vår kärlek .'), ('Min man var min första kärlek och till slutet av mitt liv jag ska älska min man .', 'Min man var min första kärlek och till slutet av mitt liv ska jag älska min man .'), ('När blev jag kär var jag 18 år gammal Jag och min kärlek gick i en klass i skolan .', 'När jag blev kär var jag 18 år gammal Jag och min kärlek gick i en klass i skolan .'), ('När jag blev kär jag var 18 år gammal Jag och min kärlek gick i en klass i skolan .', 'När jag blev kär var jag 18 år gammal Jag och min kärlek gick i en klass i skolan .'), ('En dag vi träffade varandra i skolan .', 'En dag träffade vi varandra i skolan .'), ('I alla fall jag väntade på honom i fyra år .', 'I alla fall väntade jag på honom i  ...
# 39

# %%
def pos_shorter(sentence):
    #!/usr/bin/env python3
    """Python 3 Example script for sending queries to the Sparv 2 API."""

    import json

    # URL to the Sparv 2 API:
    sparv_url = "https://ws.spraakbanken.gu.se/ws/sparv/v2/"

    # The input text to be processed by Sparv:
    sparv_input = str(sentence)

    # Optional settings, specifying what analysis should be done (in this case compound analysis only):
    # Check https://ws.spraakbanken.gu.se/ws/sparv/v2/#settings for more info
    sparv_settings = json.dumps({
        "corpus": "Korpusnamn",
        "lang": "sv",
        "textmode": "plain",
        "positional_attributes": {
            "lexical_attributes": [
                "pos",
                "msd",
                "lemma"
            ]
        },
        "text_attributes": {
            "readability_metrics": [
                "lix",
                "ovix",
                "nk"
            ]
        }
    })

    query_parameters = {"text": sparv_input, "settings": sparv_settings}


    #-------------------------------------------------------------------
    # Example using Python's built-in urllib.request
    # https://docs.python.org/3/library/urllib.request.html
    #-------------------------------------------------------------------

    import urllib.request
    import urllib.parse

    enc_query = urllib.parse.urlencode(query_parameters).encode("UTF-8")
    resp = urllib.request.urlopen(sparv_url, data=enc_query).read()
    
#     print("\nSparv response using urllib:\n")
#     o = resp.decode("UTF-8")
#     print(o)

    #-------------------------------------------------------------------
    # Example using the more intuitive but third-pary Requests library
    # https://docs.python-requests.org/en/master/
    #-------------------------------------------------------------------

    import requests

    response = requests.get(sparv_url, params=query_parameters)

#     print("\n\nSparv response using the requests library:\n")
#     print(response.text)
    
    return resp, response

# %%
def idkwhatimdoing(resp, response):
    print('ORIGINAL:')
    print("\nSparv response using urllib:\n")
    print(resp.decode("UTF-8"))
    print("\n\nSparv response using the requests library:\n")
    print(response.text)
    print('_________________________________')
    print('CORRECTED:')
    print("\nSparv response using urllib:\n")
    print(resp.decode("UTF-8"))
    print("\n\nSparv response using the requests library:\n")
    print(response.text)
    print('_________________________________')

# %%
def pos_n_words_maker(s):
    pos = []
    for line in s:
        if line.startswith('<w pos='):
            pos.append(line)
    sentence_pos_n_words = []
    for p in pos:
        p_split = p.split()
        if len(p_split) == 3:
            lemma = p_split[2] #change to lemma
            front = lemma[:lemma.index(">")] + '>'
            back = lemma[lemma.index("<"):]
            nofront = lemma.replace(front,'')
            nofrontnorback = nofront.replace(back, '')
            pos_n_word = (p_split[1][5:7], nofrontnorback) # (pos tag, word)
            sentence_pos_n_words.append(pos_n_word)
        if len(p_split) == 4:
            lemma = p_split[3]
            front = lemma[:lemma.index(">")] + '>'
            back = lemma[lemma.index("<"):]
            nofront = lemma.replace(front,'')
            nofrontnorback = nofront.replace(back, '')
            pos_n_word = (p_split[1][5:7], nofrontnorback) # (pos tag, word)
            sentence_pos_n_words.append(pos_n_word)
    return sentence_pos_n_words

# %%
import re

final = []
for p1, p2 in pairs:
    pp1, _ = pos_shorter(p1)
    pp2, _ = pos_shorter(p2)
    pp1 = pp1.decode("UTF-8")
    pp2 = pp2.decode("UTF-8")
#     a = a.text
    s1 = pp1.splitlines()
    s2 = pp2.splitlines()
    
    p_n_w1 = pos_n_words_maker(s1)
    p_n_w2 = pos_n_words_maker(s2)
    final.append((p_n_w1, p_n_w2))

# %%
print(final)
# Out:
# [([('HA', 'När'), ('PN', 'jag'), ('VB', 'kom'), ('AB', 'först'), ('RG', '2012'), ('PN', 'jag'), ('VB', 'bodde'), ('PP', 'i'), ('DT', 'en'), ('JJ', 'kommunal'), ('NN', 'lägenhet'), ('PP', 'med'), ('RG', '3'), ('JJ', 'andra'), ('NN', 'personer'), ('MA', '.')], [('HA', 'När'), ('PN', 'jag'), ('AB', 'först'), ('VB', 'kom'), ('RG', '2012'), ('VB', 'bodde'), ('PN', 'jag'), ('PP', 'i'), ('DT', 'en'), ('JJ', 'kommunal'), ('NN', 'lägenhet'), ('PP', 'med'), ('RG', '3'), ('JJ', 'andra'), ('NN', 'personer'), ('MA', '.')]), ([('AB', 'Ibland'), ('PN', 'vi'), ('VB', 'kan'), ('VB', 'titta'), ('KN', 'och'), ('VB', 'lyssna'), ('PP', 'på'), ('HA', 'hur'), ('PN', 'det'), ('VB', 'funkar'), ('MA', '.')], [('AB', 'Ibland'), ('VB', 'kan'), ('PN', 'vi'), ('VB', 'titta'), ('KN', 'och'), ('VB', 'lyssna'), ('PP', 'på'), ('HA', 'hur'), ('PN', 'det'), ('VB', 'funkar'), ('MA', '.')]), ([('AB', 'Ibland'), ('VB', 'kan'), ('PN', 'vi'), ('VB', 'titta'), ('KN', 'och'), ('VB', 'lyssna'), ('PP', 'på'), ('HA', 'hur'), ('VB', 'funkar'), ('PN', 'det'), ('MA', '.')], [('AB', 'Ibland'), ('VB', 'kan'), ('PN', 'vi'), ('VB', 'titta'), ('KN', 'och'), ('VB', 'lyssna'), ('PP', 'på'), ('HA', 'hur'), ('PN', 'det'), ('VB', 'funkar'), ('MA', '.')]), ([('KN', 'Men'), ('AB', 'nu'), ('PN', 'jag'), ('VB', 'är'), ('AB', 'inte'), ('PC', 'intresserad'), ('PP', 'av'), ('DT', 'den'), ('JJ', 'längre'), ('MA', '.')], [('KN', 'Men'), ('AB', 'nu'), ('VB', 'är'), ('PN', 'jag'), ('AB', 'inte'), ('PC', 'intresserad'), ('PP', 'av'), ('DT', 'den'), ('JJ', 'längre'), ('MA', '.')]), ([('AB', 'Dessutom'), ('NN', 'kursen'), ('AB', 'inte'), ('JJ', 'bra'), ('PP', 'för'), ('MA', '.')], [('AB', 'Dessutom'), ('NN', 'kursen'), ('AB', 'inte'), ('JJ', 'bra'), ('PP', 'för'), ('MA', '.')]), ([('AB', 'Tyvärr'), ('PN', 'någonting'), ('VB', 'har'), ('VB', 'hänt'), ('HP', 'som'), ('VB', 'gör'), ('SN', 'att'), ('PN', 'jag'), ('AB', 'inte'), ('VB', 'kan'), ('VB', 'gå'), ('PP', 'på'), ('NN', 'kursen'), ('KN', 'och'), ('PN', 'jag'), ('VB', 'önskar'), ('IE', 'att'), ('VB', 'få'), ('NN', 'pengarna'), ('AB', 'tillbaka'), ('MA', '.')], [('AB', 'Tyvärr'), ('VB', 'har'), ('PN', 'någonting'), ('VB', 'hänt'), ('HP', 'som'), ('VB', 'gör'), ('SN', 'att'), ('PN', 'jag'), ('AB', 'inte'), ('VB', 'kan'), ('VB', 'gå'), ('PP', 'på'), ('NN', 'kursen'), ('KN', 'och'), ('PN', 'jag'), ('VB', 'önskar'), ('IE', 'att'), ('VB', 'få'), ('NN', 'pengarna'), ('AB', 'tillbaka'), ('MA', '.')]), ([('PP', 'För'), ('DT', 'det'), ('RO', 'första'), ('VB', 'måste'), ('PN', 'jag'), ('VB', 'stanna'), ('AB', 'där'), ('AB', 'lite'), ('AB', 'längre'), ('AB', 'så'), ('VB', 'kan'), ('PN', 'jag'), ('AB', 'inte'), ('VB', 'börja'), ('PP', 'på'), ('NN', 'kursen'), ('MA', '.')], [('PP', 'För'), ('DT', 'det'), ('RO', 'första'), ('VB', 'måste'), ('PN', 'jag'), ('VB', 'stanna'), ('AB', 'där'), ('AB', 'lite'), ('AB', 'längre'), ('KN', 'så'), ('PN', 'jag'), ('VB', 'kan'), ('AB', 'inte'), ('VB', 'börja'), ('PP', 'på'), ('NN', 'kursen'), ('MA', '.')]), ([('VB', 'har'), ('PN', 'jag'), ('AB', 'lite'), ('NN', 'pengar'), ('KN', 'och'), ('VB', 'behöver'), ('PN', 'jag'), ('AB', 'mer'), ('NN', 'pengar'), ('PP', 'för'), ('IE', 'att'), ('VB', 'betala'), ('PP', 'för'), ('NN', 'biljetterna'), ('PP', 'för'), ('NN', 'resan'), ('MA', '.')], [('VB', 'har'), ('PN', 'jag'), ('AB', 'lite'), ('NN', 'pengar'), ('KN', 'och'), ('PN', 'jag'), ('VB', 'behöver'), ('AB', 'mer'), ('NN', 'pengar'), ('PP', 'för'), ('IE', 'att'), ('VB', 'betala'), ('PP', 'för'), ('NN', 'biljetterna'), ('PP', 'för'), ('NN', 'resan'), ('MA', '.')]), ([('AB', 'Så'), ('VB', 'önskar'), ('PN', 'jag'), ('SN', 'att'), ('PN', 'du'), ('VB', 'betalar'), ('PL', 'tillbaka'), ('PS', 'min'), ('NN', 'kursavgift'), ('AB', 'så'), ('AB', 'snart'), ('KN', 'som'), ('JJ', 'möjligt'), ('MA', '.')], [('KN', 'Så'), ('PN', 'jag'), ('VB', 'önskar'), ('SN', 'att'), ('PN', 'du'), ('VB', 'betalar'), ('PL', 'tillbaka'), ('PS', 'min'), ('NN', 'kursavgift'), ('AB', 'så'), ('AB', 'snart'), ('KN', 'som'), ('JJ', 'möjligt'), ('MA', '.')]), ([('HA', 'Där ...

# %%
print(len(final[0]))
# Out:
# 2

# %%
a = ([('AB', 'Så'), ('VB', 'önskar'), ('PN', 'jag'), ('SN', 'att'), ('PN', 'du'), ('VB', 'betalar'), ('PL', 'tillbaka'), ('PS', 'min'), ('NN', 'kursavgift'), ('AB', 'så'), ('AB', 'snart'), ('KN', 'som'), ('JJ', 'möjligt'), ('MA', '.')], [('KN', 'Så'), ('PN', 'jag'), ('VB', 'önskar'), ('SN', 'att'), ('PN', 'du'), ('VB', 'betalar'), ('PL', 'tillbaka'), ('PS', 'min'), ('NN', 'kursavgift'), ('AB', 'så'), ('AB', 'snart'), ('KN', 'som'), ('JJ', 'möjligt'), ('MA', '.')])

df1 = pd.DataFrame(a[0], columns =['POS og', 'Word og'])
df2 = pd.DataFrame(a[1], columns =['POS cr', 'Word cr'])

frames = [df1, df2]
  
result = pd.concat(frames, axis=1, join='inner')
print(result)
# Out:
#    POS og     Word og POS cr     Word cr
# 0      AB          Så     KN          Så
# 1      VB      önskar     PN         jag
# 2      PN         jag     VB      önskar
# 3      SN         att     SN         att
# 4      PN          du     PN          du
# 5      VB     betalar     VB     betalar
# 6      PL    tillbaka     PL    tillbaka
# 7      PS         min     PS         min
# 8      NN  kursavgift     NN  kursavgift
# 9      AB          så     AB          så
# 10     AB       snart     AB       snart
# 11     KN         som     KN         som
# 12     JJ     möjligt     JJ     möjligt
# 13     MA           .     MA           .

# %%
def difference_finder(sent_tuple):
    a, b = sent_tuple
    d = []
    for i, word in enumerate(a):
        if word[1] == b[i][1]:
            pass
        else:
            difference = (word[0], b[i][0]) #keep the tags
            d.append(difference)
    if d:
        if len(d) == 2:
            return d[0]
        else:
            return [d[0], d[2]]

# %%
def difference_finder_plus(sent_tuple):
    a, b = sent_tuple
    d = []
    prevs = []
    print("original sentence:", a)
    print("corrected sentence:", b)
    for i, word in enumerate(a):
        if word[1] == b[i][1]:
            pass
        else:
            prevs.append(a[i-1])
            print('previous word:', a[i-1])
            print('index:', i)
            difference = (word[0], b[i][0]) #keep the tags
            d.append(difference)
    print("difference tags:", d)
    print("_____________________________________________________________________________________________")
    if d:
        if len(d) == 2:
            return [d[0], prevs[0]]
        else:
            return [d[0], d[2], prevs[0][0]]

# %%
from collections import Counter

everything = []
for i, f in enumerate(final):
    found = difference_finder(f)
    if found != None:
        if type(found) == tuple:
            everything.append(found)
        else:
            everything.append(found[0])
            everything.append(found[1])

c = Counter(everything)
c
# Out:
# Counter({('VB', 'AB'): 2,
#          ('PN', 'VB'): 21,
#          ('VB', 'PN'): 8,
#          ('NN', 'VB'): 1,
#          ('PS', 'VB'): 3,
#          ('VB', 'NN'): 4,
#          ('DT', 'VB'): 1})

# %%
from collections import Counter
everything = []
befores = []
for i, f in enumerate(final):
    found = difference_finder_plus(f)
    if found != None:
        if len(found) == 2:
            everything.append(found[0])
            befores.append(found[1][0])
        else:
            everything.append(found[0])
            everything.append(found[1])
            befores.append(found[2])
# print(type(everything), type(befores))
e = Counter(everything)
b = Counter(befores)
print('Tag combination counts:', e)
print('Previous words counts:', b)
# Out:
# original sentence: [('HA', 'När'), ('PN', 'jag'), ('VB', 'kom'), ('AB', 'först'), ('RG', '2012'), ('PN', 'jag'), ('VB', 'bodde'), ('PP', 'i'), ('DT', 'en'), ('JJ', 'kommunal'), ('NN', 'lägenhet'), ('PP', 'med'), ('RG', '3'), ('JJ', 'andra'), ('NN', 'personer'), ('MA', '.')]
# corrected sentence: [('HA', 'När'), ('PN', 'jag'), ('AB', 'först'), ('VB', 'kom'), ('RG', '2012'), ('VB', 'bodde'), ('PN', 'jag'), ('PP', 'i'), ('DT', 'en'), ('JJ', 'kommunal'), ('NN', 'lägenhet'), ('PP', 'med'), ('RG', '3'), ('JJ', 'andra'), ('NN', 'personer'), ('MA', '.')]
# previous word: ('PN', 'jag')
# index: 2
# previous word: ('VB', 'kom')
# index: 3
# previous word: ('RG', '2012')
# index: 5
# previous word: ('PN', 'jag')
# index: 6
# difference tags: [('VB', 'AB'), ('AB', 'VB'), ('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('AB', 'Ibland'), ('PN', 'vi'), ('VB', 'kan'), ('VB', 'titta'), ('KN', 'och'), ('VB', 'lyssna'), ('PP', 'på'), ('HA', 'hur'), ('PN', 'det'), ('VB', 'funkar'), ('MA', '.')]
# corrected sentence: [('AB', 'Ibland'), ('VB', 'kan'), ('PN', 'vi'), ('VB', 'titta'), ('KN', 'och'), ('VB', 'lyssna'), ('PP', 'på'), ('HA', 'hur'), ('PN', 'det'), ('VB', 'funkar'), ('MA', '.')]
# previous word: ('AB', 'Ibland')
# index: 1
# previous word: ('PN', 'vi')
# index: 2
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('AB', 'Ibland'), ('VB', 'kan'), ('PN', 'vi'), ('VB', 'titta'), ('KN', 'och'), ('VB', 'lyssna'), ('PP', 'på'), ('HA', 'hur'), ('VB', 'funkar'), ('PN', 'det'), ('MA', '.')]
# corrected sentence: [('AB', 'Ibland'), ('VB', 'kan'), ('PN', 'vi'), ('VB', 'titta'), ('KN', 'och'), ('VB', 'lyssna'), ('PP', 'på'), ('HA', 'hur'), ('PN', 'det'), ('VB', 'funkar'), ('MA', '.')]
# previous word: ('HA', 'hur')
# index: 8
# previous word: ('VB', 'funkar')
# index: 9
# difference tags: [('VB', 'PN'), ('PN', 'VB')]
# _____________________________________________________________________________________________
# original sentence: [('KN', 'Men'), ('AB', 'nu'), ('PN', 'jag'), ('VB', 'är'), ('AB', 'inte'), ('PC', 'intresserad'), ('PP', 'av'), ('DT', 'den'), ('JJ', 'längre'), ('MA', '.')]
# corrected sentence: [('KN', 'Men'), ('AB', 'nu'), ('VB', 'är'), ('PN', 'jag'), ('AB', 'inte'), ('PC', 'intresserad'), ('PP', 'av'), ('DT', 'den'), ('JJ', 'längre'), ('MA', '.')]
# previous word: ('AB', 'nu')
# index: 2
# previous word: ('PN', 'jag')
# index: 3
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('AB', 'Dessutom'), ('NN', 'kursen'), ('AB', 'inte'), ('JJ', 'bra'), ('PP', 'för'), ('MA', '.')]
# corrected sentence: [('AB', 'Dessutom'), ('NN', 'kursen'), ('AB', 'inte'), ('JJ', 'bra'), ('PP', 'för'), ('MA', '.')]
# difference tags: []
# _____________________________________________________________________________________________
# original sentence: [('AB', 'Tyvärr'), ('PN', 'någonting'), ('VB', 'har'), ('VB', 'hänt'), ('HP', 'som'), ('VB', 'gör'), ('SN', 'att'), ('PN', 'jag'), ('AB', 'inte'), ('VB', 'kan'), ('VB', 'gå'), ('PP', 'på'), ('NN', 'kursen'), ('KN', 'och'), ('PN', 'jag'), ('VB', 'önskar'), ('IE', 'att'), ('VB', 'få'), ('NN', 'pengarna'), ('AB', 'tillbaka'), ('MA', '.')]
# corrected sentence: [('AB', 'Tyvärr'), ('VB', 'har'), ('PN', 'någonting'), ('VB', 'hänt'), ('HP', 'som'), ('VB', 'gör'), ('SN', 'att'), ('PN', 'jag'), ('AB', 'inte'), ('VB', 'kan'), ('VB', 'gå'), ('PP', 'på'), ('NN', 'kursen'), ('KN', 'och'), ('PN', 'jag'), ('VB', 'önskar'), ('IE', 'att'), ('VB', 'få'), ('NN', 'pengarna'), ('AB', 'tillbaka'), ('MA', '.')]
# previous word: ('AB', 'Tyvärr')
# index: 1
# previous word: ('PN', 'någonting')
# index: 2
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('PP', 'För'), ('DT', 'det'), ('RO', 'första'), ('VB', 'måste'), ('PN', 'jag'), ('VB', 'stanna'), ('AB', 'där'), ('AB', 'lite'), ('AB', 'längre'), ('AB', 'så'), ('VB', 'kan'), ('PN', 'jag'), ('AB', 'inte'), ('VB', 'börja'), ('PP', 'på'), ('NN', 'kursen'), ('MA', '.')]
# corrected sentence: [('PP', 'För'), ('DT', 'det'), ('RO', 'första'), ('VB', 'måste'), ('PN', 'jag'), ('VB', 'stanna'), ('AB', 'där'), ('AB', 'lite'), ('AB', 'längre'), ('KN', 'så'), ('PN', 'jag'), ('VB', 'kan'), ('AB', 'inte'), ('VB', 'börja'), ('PP', 'på'), ('NN', 'kursen'), ('MA', '.')]
# previous word: ('AB', 'så')
# index: 10
# previous word: ('VB', 'kan')
# index: 11
# difference tags: [('VB', 'PN'), ('PN', 'VB')]
# _____________________________________________________________________________________________
# original sentence: [('VB', 'har'), ('PN', 'jag'), ('AB', 'lite'), ('NN', 'pengar'), ('KN', 'och'), ('VB', 'behöver'), ('PN', 'jag'), ('AB', 'mer'), ('NN', 'pengar'), ('PP', 'för'), ('IE', 'att'), ('VB', 'betala'), ('PP', 'för'), ('NN', 'biljetterna'), ('PP', 'för'), ('NN', 'resan'), ('MA', '.')]
# corrected sentence: [('VB', 'har'), ('PN', 'jag'), ('AB', 'lite'), ('NN', 'pengar'), ('KN', 'och'), ('PN', 'jag'), ('VB', 'behöver'), ('AB', 'mer'), ('NN', 'pengar'), ('PP', 'för'), ('IE', 'att'), ('VB', 'betala'), ('PP', 'för'), ('NN', 'biljetterna'), ('PP', 'för'), ('NN', 'resan'), ('MA', '.')]
# previous word: ('KN', 'och')
# index: 5
# previous word: ('VB', 'behöver')
# index: 6
# difference tags: [('VB', 'PN'), ('PN', 'VB')]
# _____________________________________________________________________________________________
# original sentence: [('AB', 'Så'), ('VB', 'önskar'), ('PN', 'jag'), ('SN', 'att'), ('PN', 'du'), ('VB', 'betalar'), ('PL', 'tillbaka'), ('PS', 'min'), ('NN', 'kursavgift'), ('AB', 'så'), ('AB', 'snart'), ('KN', 'som'), ('JJ', 'möjligt'), ('MA', '.')]
# corrected sentence: [('KN', 'Så'), ('PN', 'jag'), ('VB', 'önskar'), ('SN', 'att'), ('PN', 'du'), ('VB', 'betalar'), ('PL', 'tillbaka'), ('PS', 'min'), ('NN', 'kursavgift'), ('AB', 'så'), ('AB', 'snart'), ('KN', 'som'), ('JJ', 'möjligt'), ('MA', '.')]
# previous word: ('AB', 'Så')
# index: 1
# previous word: ('VB', 'önskar')
# index: 2
# difference tags: [('VB', 'PN'), ('PN', 'VB')]
# _____________________________________________________________________________________________
# original sentence: [('HA', 'Därför'), ('PN', 'jag'), ('VB', 'vill'), ('AB', 'inte'), ('VB', 'flytta'), ('MA', '.')]
# corrected sentence: [('AB', 'Därför'), ('VB', 'vill'), ('PN', 'jag'), ('AB', 'inte'), ('VB', 'flytta'), ('MA', '.')]
# previous word: ('HA', 'Därför')
# index: 1
# previous word: ('PN', 'jag')
# index: 2
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('AB', 'Pga'), ('JJ', 'såna'), ('NN', 'grejer'), ('PN', 'jag'), ('VB', 'funderar'), ('PP', 'på'), ('IE', 'att'), ('VB', 'köpa'), ('DT', 'en'), ('JJ', 'egen'), ('NN', 'lägenhet'), ('MA', '.')]
# corrected sentence: [('AB', 'Pga'), ('JJ', 'såna'), ('NN', 'grejer'), ('VB', 'funderar'), ('PN', 'jag'), ('PP', 'på'), ('IE', 'att'), ('VB', 'köpa'), ('DT', 'en'), ('JJ', 'egen'), ('NN', 'lägenhet'), ('MA', '.')]
# previous word: ('NN', 'grejer')
# index: 3
# previous word: ('PN', 'jag')
# index: 4
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('AB', 'Ibland'), ('NN', 'mormor'), ('VB', 'kommer'), ('PP', 'för'), ('IE', 'att'), ('VB', 'stanna'), ('PP', 'med'), ('PN', 'oss'), ('JJ', 'flera'), ('NN', 'dagar'), ('MA', '.')]
# corrected sentence: [('AB', 'Ibland'), ('VB', 'kommer'), ('NN', 'mormor'), ('PP', 'för'), ('IE', 'att'), ('VB', 'stanna'), ('PP', 'med'), ('PN', 'oss'), ('JJ', 'flera'), ('NN', 'dagar'), ('MA', '.')]
# previous word: ('AB', 'Ibland')
# index: 1
# previous word: ('NN', 'mormor')
# index: 2
# difference tags: [('NN', 'VB'), ('VB', 'NN')]
# _____________________________________________________________________________________________
# original sentence: [('HA', 'När'), ('PN', 'man'), ('VB', 'flyttar'), ('PP', 'till'), ('DT', 'en'), ('JJ', 'ny'), ('NN', 'stad'), ('PN', 'man'), ('VB', 'är'), ('JJ', 'ensam'), ('DT', 'de'), ('RO', 'första'), ('NN', 'dagarna'), ('MA', '.')]
# corrected sentence: [('HA', 'När'), ('PN', 'man'), ('VB', 'flyttar'), ('PP', 'till'), ('DT', 'en'), ('JJ', 'ny'), ('NN', 'stad'), ('VB', 'är'), ('PN', 'man'), ('JJ', 'ensam'), ('DT', 'de'), ('RO', 'första'), ('NN', 'dagarna'), ('MA', '.')]
# previous word: ('NN', 'stad')
# index: 7
# previous word: ('PN', 'man')
# index: 8
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('AB', 'Nu'), ('PS', 'min'), ('NN', 'lärare'), ('VB', 'heter'), ('PM', 'Karin'), ('MA', '.')]
# corrected sentence: [('AB', 'Nu'), ('VB', 'heter'), ('PS', 'min'), ('NN', 'lärare'), ('PM', 'Karin'), ('MA', '.')]
# previous word: ('AB', 'Nu')
# index: 1
# previous word: ('PS', 'min')
# index: 2
# previous word: ('NN', 'lärare')
# index: 3
# difference tags: [('PS', 'VB'), ('NN', 'PS'), ('VB', 'NN')]
# _____________________________________________________________________________________________
# original sentence: [('HA', 'Därför'), ('PN', 'jag'), ('VB', 'tycker'), ('PP', 'om'), ('NN', 'havet'), ('MA', '.')]
# corrected sentence: [('AB', 'Därför'), ('VB', 'tycker'), ('PN', 'jag'), ('PP', 'om'), ('NN', 'havet'), ('MA', '.')]
# previous word: ('HA', 'Därför')
# index: 1
# previous word: ('PN', 'jag')
# index: 2
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('SN', 'Om'), ('PN', 'man'), ('VB', 'vill'), ('VB', 'äta'), ('NN', 'fisk'), ('PN', 'man'), ('VB', 'kan'), ('VB', 'gå'), ('PP', 'till'), ('NN', 'havet'), ('KN', 'och'), ('VB', 'hitta'), ('NN', 'fisk'), ('PP', 'i'), ('PN', 'det'), ('MA', '.')]
# corrected sentence: [('SN', 'Om'), ('PN', 'man'), ('VB', 'vill'), ('VB', 'äta'), ('NN', 'fisk'), ('VB', 'kan'), ('PN', 'man'), ('VB', 'gå'), ('PP', 'till'), ('NN', 'havet'), ('KN', 'och'), ('VB', 'hitta'), ('NN', 'fisk'), ('PP', 'i'), ('PN', 'det'), ('MA', '.')]
# previous word: ('NN', 'fisk')
# index: 5
# previous word: ('PN', 'man')
# index: 6
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('HA', 'När'), ('PN', 'jag'), ('VB', 'blir'), ('JJ', 'arg'), ('PN', 'jag'), ('VB', 'vill'), ('VB', 'gå'), ('PP', 'till'), ('NN', 'havet'), ('KN', 'och'), ('VB', 'titta'), ('PP', 'på'), ('PN', 'det'), ('SN', 'så'), ('PN', 'jag'), ('VB', 'blir'), ('JJ', 'lugn'), ('MA', '.')]
# corrected sentence: [('HA', 'När'), ('PN', 'jag'), ('VB', 'blir'), ('JJ', 'arg'), ('VB', 'vill'), ('PN', 'jag'), ('VB', 'gå'), ('PP', 'till'), ('NN', 'havet'), ('KN', 'och'), ('VB', 'titta'), ('PP', 'på'), ('PN', 'det'), ('SN', 'så'), ('PN', 'jag'), ('VB', 'blir'), ('JJ', 'lugn'), ('MA', '.')]
# previous word: ('JJ', 'arg')
# index: 4
# previous word: ('PN', 'jag')
# index: 5
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('HA', 'När'), ('PN', 'man'), ('PN', 'man'), ('VB', 'ser'), ('NN', 'natur'), ('KN', 'som'), ('JJ', 'många'), ('NN', 'träd'), ('KN', 'och'), ('NN', 'stränder'), ('MA', '.')]
# corrected sentence: [('HA', 'När'), ('PN', 'man'), ('VB', 'ser'), ('PN', 'man'), ('NN', 'natur'), ('KN', 'som'), ('JJ', 'många'), ('NN', 'träd'), ('KN', 'och'), ('NN', 'stränder'), ('MA', '.')]
# previous word: ('PN', 'man')
# index: 2
# previous word: ('PN', 'man')
# index: 3
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('AB', 'Där'), ('DT', 'alla'), ('NN', 'människor'), ('VB', 'är'), ('JJ', 'snälla'), ('KN', 'och'), ('JJ', 'hjälpsamma'), ('MA', '.')]
# corrected sentence: [('AB', 'Där'), ('VB', 'är'), ('DT', 'alla'), ('NN', 'människor'), ('JJ', 'snälla'), ('KN', 'och'), ('JJ', 'hjälpsamma'), ('MA', '.')]
# previous word: ('AB', 'Där')
# index: 1
# previous word: ('DT', 'alla')
# index: 2
# previous word: ('NN', 'människor')
# index: 3
# difference tags: [('DT', 'VB'), ('NN', 'DT'), ('VB', 'NN')]
# _____________________________________________________________________________________________
# original sentence: [('PN', 'Jag'), ('VB', 'tycker'), ('PP', 'om'), ('IE', 'att'), ('VB', 'bo'), ('NN', 'tillsamans'), ('PP', 'med'), ('PS', 'min'), ('NN', 'sambo'), ('KN', 'men'), ('AB', 'ibland'), ('PN', 'det'), ('VB', 'är'), ('AB', 'lite'), ('JJ', 'svårt'), ('MA', '.')]
# corrected sentence: [('PN', 'Jag'), ('VB', 'tycker'), ('PP', 'om'), ('IE', 'att'), ('VB', 'bo'), ('NN', 'tillsamans'), ('PP', 'med'), ('PS', 'min'), ('NN', 'sambo'), ('KN', 'men'), ('AB', 'ibland'), ('VB', 'är'), ('PN', 'det'), ('AB', 'lite'), ('JJ', 'svårt'), ('MA', '.')]
# previous word: ('AB', 'ibland')
# index: 11
# previous word: ('PN', 'det')
# index: 12
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('HA', 'Där'), ('PN', 'jag'), ('VB', 'bodde'), ('PP', 'i'), ('NN', 'A-stad'), ('PP', 'med'), ('PS', 'min'), ('NN', 'mamma'), ('KN', 'och'), ('PS', 'hennes'), ('NN', 'hundar'), ('PP', 'i'), ('PS', 'hennes'), ('NN', 'hus'), ('MA', '.')]
# corrected sentence: [('AB', 'Där'), ('VB', 'bodde'), ('PN', 'jag'), ('PP', 'i'), ('NN', 'A-stad'), ('PP', 'med'), ('PS', 'min'), ('NN', 'mamma'), ('KN', 'och'), ('PS', 'hennes'), ('NN', 'hundar'), ('PP', 'i'), ('PS', 'hennes'), ('NN', 'hus'), ('MA', '.')]
# previous word: ('HA', 'Där')
# index: 1
# previous word: ('PN', 'jag')
# index: 2
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('PN', 'jag'), ('VB', 'är'), ('JJ', 'jätteglad'), ('IE', 'att'), ('VB', 'bo'), ('AB', 'där'), ('MA', '.')]
# corrected sentence: [('VB', 'är'), ('PN', 'jag'), ('JJ', 'jätteglad'), ('IE', 'att'), ('VB', 'bo'), ('AB', 'där'), ('MA', '.')]
# previous word: ('MA', '.')
# index: 0
# previous word: ('PN', 'jag')
# index: 1
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('PP', 'Från'), ('PS', 'mitt'), ('NN', 'fönster'), ('PN', 'jag'), ('VB', 'kan'), ('VB', 'se'), ('NN', 'Strandvägen-gen'), ('NN', 'busshållplats'), ('MA', '.')]
# corrected sentence: [('PP', 'Från'), ('PS', 'mitt'), ('NN', 'fönster'), ('VB', 'kan'), ('PN', 'jag'), ('VB', 'se'), ('NN', 'Strandvägen-gen'), ('NN', 'busshållplats'), ('MA', '.')]
# previous word: ('NN', 'fönster')
# index: 3
# previous word: ('PN', 'jag')
# index: 4
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('JJ', 'Nästa'), ('NN', 'dag'), ('PN', 'hon'), ('PP', 'till'), ('KN', 'och'), ('VB', 'berättade'), ('DT', 'samma'), ('NN', 'sak'), ('PP', 'för'), ('PN', 'mig'), ('KN', 'och'), ('PN', 'jag'), ('VB', 'blev'), ('AB', 'väldigt'), ('JJ', 'glad'), ('KN', 'och'), ('PN', 'vi'), ('VB', 'träffades'), ('DT', 'varje'), ('NN', 'dag'), ('MA', '.')]
# corrected sentence: [('JJ', 'Nästa'), ('NN', 'dag'), ('PN', 'hon'), ('PP', 'till'), ('KN', 'och'), ('VB', 'berättade'), ('DT', 'samma'), ('NN', 'sak'), ('PP', 'för'), ('PN', 'mig'), ('KN', 'och'), ('PN', 'jag'), ('VB', 'blev'), ('AB', 'väldigt'), ('JJ', 'glad'), ('KN', 'och'), ('PN', 'vi'), ('VB', 'träffades'), ('DT', 'varje'), ('NN', 'dag'), ('MA', '.')]
# difference tags: []
# _____________________________________________________________________________________________
# original sentence: [('AB', 'Så'), ('PS', 'vår'), ('NN', 'kärlek'), ('VB', 'började'), ('MA', '.')]
# corrected sentence: [('AB', 'Så'), ('VB', 'började'), ('PS', 'vår'), ('NN', 'kärlek'), ('MA', '.')]
# previous word: ('AB', 'Så')
# index: 1
# previous word: ('PS', 'vår')
# index: 2
# previous word: ('NN', 'kärlek')
# index: 3
# difference tags: [('PS', 'VB'), ('NN', 'PS'), ('VB', 'NN')]
# _____________________________________________________________________________________________
# original sentence: [('PS', 'Min'), ('NN', 'man'), ('VB', 'var'), ('PS', 'min'), ('RO', 'första'), ('NN', 'kärlek'), ('KN', 'och'), ('PP', 'av'), ('PS', 'mitt'), ('NN', 'liv'), ('PN', 'jag'), ('VB', 'ska'), ('VB', 'älska'), ('PS', 'min'), ('NN', 'man'), ('MA', '.')]
# corrected sentence: [('PS', 'Min'), ('NN', 'man'), ('VB', 'var'), ('PS', 'min'), ('RO', 'första'), ('NN', 'kärlek'), ('KN', 'och'), ('PP', 'av'), ('PS', 'mitt'), ('NN', 'liv'), ('VB', 'ska'), ('PN', 'jag'), ('VB', 'älska'), ('PS', 'min'), ('NN', 'man'), ('MA', '.')]
# previous word: ('NN', 'liv')
# index: 10
# previous word: ('PN', 'jag')
# index: 11
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('HA', 'När'), ('VB', 'blev'), ('PN', 'jag'), ('JJ', 'kär'), ('VB', 'var'), ('PN', 'jag'), ('RG', '18'), ('NN', 'år'), ('JJ', 'gammal'), ('PN', 'Jag'), ('KN', 'och'), ('PS', 'min'), ('NN', 'kärlek'), ('VB', 'gick'), ('PP', 'i'), ('DT', 'en'), ('NN', 'klass'), ('PP', 'i'), ('NN', 'skolan'), ('MA', '.')]
# corrected sentence: [('HA', 'När'), ('PN', 'jag'), ('VB', 'blev'), ('JJ', 'kär'), ('VB', 'var'), ('PN', 'jag'), ('RG', '18'), ('NN', 'år'), ('JJ', 'gammal'), ('PN', 'Jag'), ('KN', 'och'), ('PS', 'min'), ('NN', 'kärlek'), ('VB', 'gick'), ('PP', 'i'), ('DT', 'en'), ('NN', 'klass'), ('PP', 'i'), ('NN', 'skolan'), ('MA', '.')]
# previous word: ('HA', 'När')
# index: 1
# previous word: ('VB', 'blev')
# index: 2
# difference tags: [('VB', 'PN'), ('PN', 'VB')]
# _____________________________________________________________________________________________
# original sentence: [('HA', 'När'), ('PN', 'jag'), ('VB', 'blev'), ('JJ', 'kär'), ('PN', 'jag'), ('VB', 'var'), ('RG', '18'), ('NN', 'år'), ('JJ', 'gammal'), ('PN', 'Jag'), ('KN', 'och'), ('PS', 'min'), ('NN', 'kärlek'), ('VB', 'gick'), ('PP', 'i'), ('DT', 'en'), ('NN', 'klass'), ('PP', 'i'), ('NN', 'skolan'), ('MA', '.')]
# corrected sentence: [('HA', 'När'), ('PN', 'jag'), ('VB', 'blev'), ('JJ', 'kär'), ('VB', 'var'), ('PN', 'jag'), ('RG', '18'), ('NN', 'år'), ('JJ', 'gammal'), ('PN', 'Jag'), ('KN', 'och'), ('PS', 'min'), ('NN', 'kärlek'), ('VB', 'gick'), ('PP', 'i'), ('DT', 'en'), ('NN', 'klass'), ('PP', 'i'), ('NN', 'skolan'), ('MA', '.')]
# previous word: ('JJ', 'kär')
# index: 4
# previous word: ('PN', 'jag')
# index: 5
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('DT', 'En'), ('NN', 'dag'), ('PN', 'vi'), ('VB', 'träffade'), ('PN', 'varandra'), ('PP', 'i'), ('NN', 'skolan'), ('MA', '.')]
# corrected sentence: [('DT', 'En'), ('NN', 'dag'), ('VB', 'träffade'), ('PN', 'vi'), ('PN', 'varandra'), ('PP', 'i'), ('NN', 'skolan'), ('MA', '.')]
# previous word: ('NN', 'dag')
# index: 2
# previous word: ('PN', 'vi')
# index: 3
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('PN', 'jag'), ('VB', 'väntade'), ('PP', 'på'), ('PN', 'honom'), ('PP', 'i'), ('RG', 'fyra'), ('NN', 'år'), ('MA', '.')]
# corrected sentence: [('VB', 'väntade'), ('PN', 'jag'), ('PP', 'på'), ('PN', 'honom'), ('PP', 'i'), ('RG', 'fyra'), ('NN', 'år'), ('MA', '.')]
# previous word: ('MA', '.')
# index: 0
# previous word: ('PN', 'jag')
# index: 1
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('AB', 'Ibland'), ('PN', 'man'), ('VB', 'brukar'), ('VB', 'säga'), ('SN', 'att'), ('NN', 'kärleken'), ('VB', 'har'), ('DT', 'ingen'), ('NN', 'gräns'), ('KN', 'och'), ('PN', 'det'), ('VB', 'är'), ('JJ', 'sant'), ('MA', '.')]
# corrected sentence: [('AB', 'Ibland'), ('VB', 'brukar'), ('PN', 'man'), ('VB', 'säga'), ('SN', 'att'), ('NN', 'kärleken'), ('VB', 'har'), ('DT', 'ingen'), ('NN', 'gräns'), ('KN', 'och'), ('PN', 'det'), ('VB', 'är'), ('JJ', 'sant'), ('MA', '.')]
# previous word: ('AB', 'Ibland')
# index: 1
# previous word: ('PN', 'man')
# index: 2
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# original sentence: [('PN', 'Vi'), ('VB', 'var'), ('NN', 'klasskamrater'), ('NN', 'grundskolan'), ('KN', 'och'), ('PP', 'sedan'), ('PS', 'min'), ('NN', 'vän'), ('VB', 'reste'), ('PP', 'till'), ('DT', 'ett'), ('JJ', 'avlägset'), ('NN', 'land'), ('MA', '.')]
# corrected sentence: [('PN', 'Vi'), ('VB', 'var'), ('NN', 'klasskamrater'), ('NN', 'grundskolan'), ('KN', 'och'), ('AB', 'sedan'), ('VB', 'reste'), ('PS', 'min'), ('NN', 'vän'), ('PP', 'till'), ('DT', 'ett'), ('JJ', 'avlägset'), ('NN', 'land'), ('MA', '.')]
# previous word: ('PP', 'sedan')
# index: 6
# previous word: ('PS', 'min')
# index: 7
# previous word: ('NN', 'vän')
# index: 8
# difference tags: [('PS', 'VB'), ('NN', 'PS'), ('VB', 'NN')]
# _____________________________________________________________________________________________
# original sentence: [('DT', 'Varje'), ('NN', 'dag'), ('VB', 'pratade'), ('PN', 'vi'), ('PP', 'efter'), ('DT', 'det'), ('KN', 'och'), ('VB', 'började'), ('PN', 'jag'), ('VB', 'bli'), ('AB', 'väldigt'), ('JJ', 'glad'), ('MA', '.')]
# corrected sentence: [('DT', 'Varje'), ('NN', 'dag'), ('VB', 'pratade'), ('PN', 'vi'), ('PP', 'efter'), ('DT', 'det'), ('KN', 'och'), ('PN', 'jag'), ('VB', 'började'), ('VB', 'bli'), ('AB', 'väldigt'), ('JJ', 'glad'), ('MA', '.')]
# previous word: ('KN', 'och')
# index: 7
# previous word: ('VB', 'började')
# index: 8
# difference tags: [('VB', 'PN'), ('PN', 'VB')]
# _____________________________________________________________________________________________
# original sentence: [('PN', 'Jag'), ('VB', 'var'), ('PC', 'fascinerad'), ('PP', 'av'), ('PN', 'henne'), ('KN', 'och'), ('HA', 'när'), ('PN', 'jag'), ('VB', 'kollar'), ('PP', 'på'), ('PN', 'henne'), ('VB', 'börjar'), ('PS', 'mitt'), ('NN', 'hjärta'), ('VB', 'slå'), ('AB', 'så'), ('AB', 'hårt'), ('SN', 'tills'), ('PN', 'jag'), ('VB', 'känner'), ('SN', 'att'), ('PN', 'jag'), ('VB', 'kan'), ('AB', 'inte'), ('VB', 'andas'), ('KN', 'och'), ('PN', 'jag'), ('VB', 'blir'), ('JJ', 'röd'), ('PP', 'i'), ('NN', 'ansiktet'), ('MA', '.')]
# corrected sentence: [('PN', 'Jag'), ('VB', 'var'), ('PC', 'fascinerad'), ('PP', 'av'), ('PN', 'henne'), ('KN', 'och'), ('HA', 'när'), ('PN', 'jag'), ('VB', 'kollar'), ('PP', 'på'), ('PN', 'henne'), ('VB', 'börjar'), ('PS', 'mitt'), ('NN', 'hjärta'), ('VB', 'slå'), ('AB', 'så'), ('AB', 'hårt'), ('SN', 'tills'), ('PN', 'jag'), ('VB', 'känner'), ('SN', 'att'), ('PN', 'jag'), ('AB', 'inte'), ('VB', 'kan'), ('VB', 'andas'), ('KN', 'och'), ('PN', 'jag'), ('VB', 'blir'), ('JJ', 'röd'), ('PP', 'i'), ('NN', 'ansiktet'), ('MA', '.')]
# previous word: ('PN', 'jag')
# index: 22
# previous word: ('VB', 'kan')
# index: 23
# difference tags: [('VB', 'AB'), ('AB', 'VB')]
# _____________________________________________________________________________________________
# original sentence: [('RG', '10'), ('NN', 'månader'), ('AB', 'därefter'), ('PN', 'vi'), ('PP', 'för'), ('IE', 'att'), ('VB', 'sluta'), ('VB', 'träffa'), ('PN', 'varandra'), ('MA', '.')]
# corrected sentence: [('RG', '10'), ('NN', 'månader'), ('AB', 'därefter'), ('PN', 'vi'), ('PP', 'för'), ('IE', 'att'), ('VB', 'sluta'), ('VB', 'träffa'), ('PN', 'varandra'), ('MA', '.')]
# difference tags: []
# _____________________________________________________________________________________________
# original sentence: [('PN', 'Vi'), ('VB', 'har'), ('RG', 'två'), ('NN', 'båtar'), ('HP', 'som'), ('VB', 'åker'), ('PN', 'vi'), ('PP', 'i'), ('PP', 'för'), ('IE', 'att'), ('VB', 'fiska'), ('KN', 'och'), ('VB', 'simma'), ('MA', '.')]
# corrected sentence: [('PN', 'Vi'), ('VB', 'har'), ('RG', 'två'), ('NN', 'båtar'), ('HP', 'som'), ('PN', 'vi'), ('VB', 'åker'), ('PP', 'i'), ('PP', 'för'), ('IE', 'att'), ('VB', 'fiska'), ('KN', 'och'), ('VB', 'simma'), ('MA', '.')]
# previous word: ('HP', 'som')
# index: 5
# previous word: ('VB', 'åker')
# index: 6
# difference tags: [('VB', 'PN'), ('PN', 'VB')]
# _____________________________________________________________________________________________
# original sentence: [('PP', 'På'), ('NN', 'hösten'), ('PN', 'vi'), ('AB', 'ibland'), ('PP', 'för'), ('IE', 'att'), ('VB', 'plocka'), ('NN', 'svamp'), ('KN', 'och'), ('NN', 'blåbär'), ('MA', '.')]
# corrected sentence: [('PP', 'På'), ('NN', 'hösten'), ('PN', 'vi'), ('AB', 'ibland'), ('PP', 'för'), ('IE', 'att'), ('VB', 'plocka'), ('NN', 'svamp'), ('KN', 'och'), ('NN', 'blåbär'), ('MA', '.')]
# difference tags: []
# _____________________________________________________________________________________________
# original sentence: [('NN', 'Introkursen'), ('VB', 'var'), ('JJ', 'viktig'), ('PP', 'för'), ('PN', 'dem'), ('HP', 'som'), ('VB', 'var'), ('NN', 'nybörjare'), ('KN', 'och'), ('PS', 'min'), ('RO', 'första'), ('NN', 'text'), ('VB', 'handlade'), ('PP', 'om'), ('HA', 'hur'), ('VB', 'ska'), ('PN', 'jag'), ('NN', 'svenska'), ('KN', 'och'), ('VB', 'fortsätta'), ('VB', 'utbilda'), ('PN', 'mig'), ('PP', 'i'), ('PM', 'Sverige'), ('MA', '.')]
# corrected sentence: [('NN', 'Introkursen'), ('VB', 'var'), ('JJ', 'viktig'), ('PP', 'för'), ('PN', 'dem'), ('HP', 'som'), ('VB', 'var'), ('NN', 'nybörjare'), ('KN', 'och'), ('PS', 'min'), ('RO', 'första'), ('NN', 'text'), ('VB', 'handlade'), ('PP', 'om'), ('HA', 'hur'), ('PN', 'jag'), ('VB', 'ska'), ('NN', 'svenska'), ('KN', 'och'), ('VB', 'fortsätta'), ('VB', 'utbilda'), ('PN', 'mig'), ('PP', 'i'), ('PM', 'Sverige'), ('MA', '.')]
# previous word: ('HA', 'hur')
# index: 15
# previous word: ('VB', 'ska')
# index: 16
# difference tags: [('VB', 'PN'), ('PN', 'VB')]
# _____________________________________________________________________________________________
# original sentence: [('HA', 'När'), ('PN', 'du'), ('VB', 'flyger'), ('PP', 'över'), ('PM', 'Sverige'), ('PN', 'du'), ('VB', 'kan'), ('VB', 'se'), ('AB', 'allt'), ('JJ', 'bra'), ('KN', 'och'), ('PN', 'det'), ('VB', 'är'), ('AB', 'mycket'), ('AB', 'vackert'), ('MA', '.')]
# corrected sentence: [('HA', 'När'), ('PN', 'du'), ('VB', 'flyger'), ('PP', 'över'), ('PM', 'Sverige'), ('VB', 'kan'), ('PN', 'du'), ('VB', 'se'), ('AB', 'allt'), ('JJ', 'bra'), ('KN', 'och'), ('PN', 'det'), ('VB', 'är'), ('AB', 'mycket'), ('AB', 'vackert'), ('MA', '.')]
# previous word: ('PM', 'Sverige')
# index: 5
# previous word: ('PN', 'du')
# index: 6
# difference tags: [('PN', 'VB'), ('VB', 'PN')]
# _____________________________________________________________________________________________
# Tag combination counts: Counter({('PN', 'VB'): 21, ('VB', 'PN'): 8, ('VB', 'NN'): 4, ('PS', 'VB'): 3, ('VB', 'AB'): 2, ('NN', 'VB'): 1, ('DT', 'VB'): 1})
# Previous words counts: Counter({'AB': 11, 'HA': 6, 'NN': 6, 'PN': 3, 'KN': 2, 'JJ': 2, 'MA': 2, 'PP': 1, 'HP': 1, 'PM': 1})
